# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/vanditapatidar/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.0-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
data = pd.read_csv("../Final_csv/Florida.csv")

# %%
data
# Out:
#        year  month        lat        lon       U2M       V2M  wind_speed  \
# 0      2020      5 -83.550482  30.052997 -3.420912 -7.252653    8.018953
# 1      2020     11 -83.550482  30.052997 -1.815948 -6.650823    6.894281
# 2      2020     10 -83.550482  30.052997 -2.710481 -6.873364    7.388494
# 3      2020      4 -83.550482  30.052997 -3.004606 -6.561380    7.216604
# 4      2020     12 -83.550482  30.052997 -0.760787 -5.614922    5.666229
# ...     ...    ...        ...        ...       ...       ...         ...
# 21808  2020      7 -83.181840  30.442836 -4.100317 -7.017048    8.127211
# 21809  2020      3 -83.181840  30.442836 -2.527259 -6.046835    6.553721
# 21810  2020      2 -83.181840  30.442836 -1.822026 -5.907112    6.181727
# 21811  2020      1 -83.181840  30.442836 -0.243335 -5.056340    5.062192
# 21812  2020      8 -83.181840  30.442836 -4.523295 -7.021709    8.352521
#
#          state
# 0      Florida
# 1      Florida
# 2      Florida
# 3      Florida
# 4      Florida
# ...        ...
# 21808  Florida
# 21809  Florida
# 21810  Florida
# 21811  Florida
# 21812  Florida
#
# [21813 rows x 8 columns]

# %%
one_data = data[(data['lat']== -87.454122211) & (data['lon']== 30.923300623)]

# %%
one_data
# Out:
#       year  month        lat        lon       U2M       V2M  wind_speed  \
# 6259  2020      5 -87.454122  30.923301 -3.420912 -7.252653    8.018953
# 6260  2020     11 -87.454122  30.923301 -1.815948 -6.650823    6.894281
# 6261  2020     10 -87.454122  30.923301 -2.710481 -6.873364    7.388494
# 6262  2020      4 -87.454122  30.923301 -3.004606 -6.561380    7.216604
# 6263  2020     12 -87.454122  30.923301 -0.760787 -5.614922    5.666229
# 6264  2020      6 -87.454122  30.923301 -3.165348 -5.983750    6.769394
# 6265  2020      7 -87.454122  30.923301 -4.100317 -7.017048    8.127211
# 6266  2020      3 -87.454122  30.923301 -2.527259 -6.046835    6.553721
# 6267  2020      2 -87.454122  30.923301 -1.822026 -5.907112    6.181727
# 6268  2020      1 -87.454122  30.923301 -0.243335 -5.056340    5.062192
# 6269  2020      8 -87.454122  30.923301 -4.523295 -7.021709    8.352521
#
#         state
# 6259  Florida
# 6260  Florida
# 6261  Florida
# 6262  Florida
# 6263  Florida
# 6264  Florida
# 6265  Florida
# 6266  Florida
# 6267  Florida
# 6268  Florida
# 6269  Florida

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(one_data['month'], one_data['wind_speed'], color ='maroon',width = 0.4)
plt.xlabel("Month")
plt.ylabel("Wind Speed")
plt.title("Monthly Wind Speed data for location " + str(-87.454122211) + ',' + str(30.923300623) + ' in Florida')
plt.show()

# %%
# maximum wind speed
max_wind_by_geom = data.groupby(['lon','lat']).mean().reset_index()
print(max_wind_by_geom['wind_speed'].max())
# Out:
# 6.930120442997409

# %%
# monthly mean wind speed 
monthly_avg = data.groupby('month').mean().reset_index()
print(monthly_avg)
plt.bar(monthly_avg['month'], monthly_avg['wind_speed'])
plt.title("Monthly average wind speed across Florida")
plt.xlabel("Month")
plt.ylabel("Wind Speed")
plt.show()
# Out:
#     month  year        lat        lon       U2M       V2M  wind_speed
# 0       1  2020 -82.115198  28.336385 -0.243335 -5.056340    5.062192
# 1       2  2020 -82.115198  28.336385 -1.822026 -5.907112    6.181727
# 2       3  2020 -82.115198  28.336385 -2.527259 -6.046835    6.553721
# 3       4  2020 -82.115198  28.336385 -3.004606 -6.561380    7.216604
# 4       5  2020 -82.115198  28.336385 -3.420912 -7.252653    8.018953
# 5       6  2020 -82.115198  28.336385 -3.165348 -5.983750    6.769394
# 6       7  2020 -82.115198  28.336385 -4.100317 -7.017048    8.127211
# 7       8  2020 -82.115198  28.336385 -4.523295 -7.021709    8.352521
# 8      10  2020 -82.115198  28.336385 -2.710481 -6.873364    7.388494
# 9      11  2020 -82.115198  28.336385 -1.815948 -6.650823    6.894281
# 10     12  2020 -82.115198  28.336385 -0.760787 -5.614922    5.666229

# %%
max_wind_speed_by_geom = data.groupby(['lon','lat'])['wind_speed'].describe()
max_wind_speed_by_geom.head()
# Out:
#                       count     mean       std       min       25%       50%  \
# lon       lat
# 24.551155 -81.804804   11.0  6.93012  1.036796  5.062192  6.367724  6.894281
# 24.555565 -81.785072   11.0  6.93012  1.036796  5.062192  6.367724  6.894281
# 24.562698 -81.796693   11.0  6.93012  1.036796  5.062192  6.367724  6.894281
# 24.563845 -81.733643   11.0  6.93012  1.036796  5.062192  6.367724  6.894281
# 24.566181 -81.767335   11.0  6.93012  1.036796  5.062192  6.367724  6.894281
#
#                            75%       max
# lon       lat
# 24.551155 -81.804804  7.703723  8.352521
# 24.555565 -81.785072  7.703723  8.352521
# 24.562698 -81.796693  7.703723  8.352521
# 24.563845 -81.733643  7.703723  8.352521
# 24.566181 -81.767335  7.703723  8.352521
