# %%
# !pip install windrose

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np
from math import pi
from math import sqrt
from math import atan2

# %%
from windrose import WindroseAxes

# %%
df = pd.read_csv("../Final_csv/Combined_file.csv")

# %%
df = df.dropna()

# %%
df
# Out:
#        year  month        lat        lon       U2M       V2M  wind_speed  \
# 0      2020      5 -83.550482  30.052997 -3.420912 -7.252653    8.018953
# 1      2020     11 -83.550482  30.052997 -1.815948 -6.650823    6.894281
# 2      2020     10 -83.550482  30.052997 -2.710481 -6.873364    7.388494
# 3      2020      4 -83.550482  30.052997 -3.004606 -6.561380    7.216604
# 4      2020     12 -83.550482  30.052997 -0.760787 -5.614922    5.666229
# ...     ...    ...        ...        ...       ...       ...         ...
# 67469  2020      7 -80.972182  35.362070 -1.724610 -7.114029    7.320088
# 67470  2020      3 -80.972182  35.362070 -0.073339 -5.332247    5.332751
# 67471  2020      2 -80.972182  35.362070 -0.120095 -5.707527    5.708791
# 67472  2020      1 -80.972182  35.362070  0.797993 -4.801731    4.867588
# 67473  2020      8 -80.972182  35.362070 -1.650186 -7.372461    7.554885
#
#        wind_direction           state
# 0           -2.011530         Florida
# 1           -1.837340         Florida
# 2           -1.946419         Florida
# 3           -2.000219         Florida
# 4           -1.705470         Florida
# ...               ...             ...
# 67469       -1.808632  North Carolina
# 67470       -1.584549  North Carolina
# 67471       -1.591835  North Carolina
# 67472       -1.406113  North Carolina
# 67473       -1.790998  North Carolina
#
# [67474 rows x 9 columns]

# %%
df['wind_dir_trig_to_degrees'] = df['wind_direction'] * 180/pi ## -111.6 degrees
df['wind_dir_trig_from_degrees'] = df['wind_dir_trig_to_degrees'] + 180
df['wind_dir_cardinal'] = 90 - df['wind_dir_trig_from_degrees']

# %%
df
# Out:
#        year  month        lat        lon       U2M       V2M  wind_speed  \
# 0      2020      5 -83.550482  30.052997 -3.420912 -7.252653    8.018953
# 1      2020     11 -83.550482  30.052997 -1.815948 -6.650823    6.894281
# 2      2020     10 -83.550482  30.052997 -2.710481 -6.873364    7.388494
# 3      2020      4 -83.550482  30.052997 -3.004606 -6.561380    7.216604
# 4      2020     12 -83.550482  30.052997 -0.760787 -5.614922    5.666229
# ...     ...    ...        ...        ...       ...       ...         ...
# 67469  2020      7 -80.972182  35.362070 -1.724610 -7.114029    7.320088
# 67470  2020      3 -80.972182  35.362070 -0.073339 -5.332247    5.332751
# 67471  2020      2 -80.972182  35.362070 -0.120095 -5.707527    5.708791
# 67472  2020      1 -80.972182  35.362070  0.797993 -4.801731    4.867588
# 67473  2020      8 -80.972182  35.362070 -1.650186 -7.372461    7.554885
#
#        wind_direction           state  wind_dir_trig_to_degrees  \
# 0           -2.011530         Florida               -115.252186
# 1           -1.837340         Florida               -105.271849
# 2           -1.946419         Florida               -111.521578
# 3           -2.000219         Florida               -114.604122
# 4           -1.705470         Florida                -97.716231
# ...               ...             ...                       ...
# 67469       -1.808632  North Carolina               -103.626969
# 67470       -1.584549  North Carolina                -90.787989
# 67471       -1.591835  North Carolina                -91.205408
# 67472       -1.406113  North Carolina                -80.564332
# 67473       -1.790998  North Carolina               -102.616618
#
#        wind_dir_trig_from_degrees  wind_dir_cardinal
# 0                       64.747814          25.252186
# 1                       74.728151          15.271849
# 2                       68.478422          21.521578
# 3                       65.395878          24.604122
# 4                       82.283769           7.716231
# ...                           ...                ...
# 67469                   76.373031          13.626969
# 67470                   89.212011           0.787989
# 67471                   88.794592           1.205408
# 67472                   99.435668          -9.435668
# 67473                   77.383382          12.616618
#
# [67474 rows x 12 columns]

# %%
ax = WindroseAxes.from_ax()
ax.bar(df['wind_dir_trig_from_degrees'], df['wind_speed'], normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
