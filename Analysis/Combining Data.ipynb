# %% [markdown]
# # Combining data

# %%
import pandas as pd
import numpy as np

# %%
florida = pd.read_csv("../Final_csv/Florida.csv")
new_york = pd.read_csv("../Final_csv/New_york.csv")
north_carolina = pd.read_csv("../Final_csv/North_carolina.csv")

# %%
final_file = pd.concat([florida, new_york, north_carolina])

# %%
final_file
# Out:
#        year  month        lat        lon       U2M       V2M  wind_speed  \
# 0      2020      5 -83.550482  30.052997 -3.420912 -7.252653    8.018953
# 1      2020     11 -83.550482  30.052997 -1.815948 -6.650823    6.894281
# 2      2020     10 -83.550482  30.052997 -2.710481 -6.873364    7.388494
# 3      2020      4 -83.550482  30.052997 -3.004606 -6.561380    7.216604
# 4      2020     12 -83.550482  30.052997 -0.760787 -5.614922    5.666229
# ...     ...    ...        ...        ...       ...       ...         ...
# 23546  2020      7 -80.972182  35.362070 -1.724610 -7.114029    7.320088
# 23547  2020      3 -80.972182  35.362070 -0.073339 -5.332247    5.332751
# 23548  2020      2 -80.972182  35.362070 -0.120095 -5.707527    5.708791
# 23549  2020      1 -80.972182  35.362070  0.797993 -4.801731    4.867588
# 23550  2020      8 -80.972182  35.362070 -1.650186 -7.372461    7.554885
#
#        wind_direction           state
# 0           -2.011530         Florida
# ...

# %%
final_file.to_csv("Combined_file.csv", index= False)
